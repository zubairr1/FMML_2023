# %% [markdown]
# <a href="https://colab.research.google.com/github/zubairr1/FMML_2023/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 11:09:15--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   105MB/s    in 0.7s
#
# 2024-03-31 11:09:16 (105 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12156  1709.04384v2  Generating music medleys is about finding an o...  stat
# 21696   0906.4258v1  Most accurate predictions are typically obtain...  stat
# 3303   1501.05684v1  Nonnegative matrix factorization (NMF) is a po...  stat
# 24907   1412.7626v1  Arabic is a semitic language characterized by ...    cs
# 22613  1702.08320v2  The pseudo-likelihood method is one of the mos...  stat
# ...             ...                                                ...   ...
# 1042   1608.05081v4  We present a new algorithm that significantly ...    cs
# 16042  1608.06378v1  Multimedia or spoken content presents more att...    cs
# 18630   1106.4569v1  Despite the significant progress in multiagent...    cs
# 37403  1706.01443v1  This work summarizes part of current knowledge...    cs
# 32378  1503.04996v1  Random Forest (RF) is an ensemble supervised m...    cs
#
#                                                    title  year  \
# 12156  Generating Music Medleys via Playing Music Puz...  2017
# 21696             The Feature Importance Ranking Measure  2009
# 3303   Bi-Objective Nonnegative Matrix Factorization:...  2015
# 24907  AltecOnDB: A Large-Vocabulary Arabic Online Ha...  2014
# 22613  An Efficient Pseudo-likelihood Method for Spar...  2017
# ...                                                  ...   ...
# 1042   BBQ-Networks: Efficient Exploration in Deep Re...  2016
# 16042  Towards Machine Comprehension of Spoken Conten...  2016
# 18630  The Communicative Multiagent Team Decision Pro...  2011
# 37403  Types of Cognition and its Implications for fu...  2017
# 32378  On Extreme Pruning of Random Forest Ensembles ...  2015
#
#                                                 keywords
# 12156  [generating, permutation, supervised, sequenti...
# 21696  [predictions, typically, unfortunately, access...
# 3303   [nonnegative, factorization, extraction, techn...
# 24907  [characterized, morphology, exceptional, ambig...
# 22613  [likelihood, algorithms, formulate, regularize...
# ...                                                  ...
# 1042   [algorithm, significantly, efficiency, explora...
# 16042  [multimedia, attractive, information, difficul...
# 18630  [significant, multiagent, optimality, prescrip...
# 37403  [summarizes, knowledge, cognitive, biological,...
# 32378  [supervised, technique, developed, techniques,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12156    [generating, permutation, supervised, sequenti...
# 21696    [predictions, typically, unfortunately, access...
# 3303     [nonnegative, factorization, extraction, techn...
# 24907    [characterized, morphology, exceptional, ambig...
# 22613    [likelihood, algorithms, formulate, regularize...
#                                ...
# 22921    [perspective, generative, adversarial, distrib...
# 12113    [generating, categorical, attributes, categori...
# 18727    [inference, inference, propagation, simplified...
# 3330     [previously, generating, efficient, beautiful,...
# 14617    [contrarily, approaches, annotation, technique...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8706 words.
# Out of those 4621 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="dcbafa65-2401-4e6b-8be9-c0d0b5fc48fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dcbafa65-2401-4e6b-8be9-c0d0b5fc48fb")) {                    Plotly.newPlot(                        "dcbafa65-2401-4e6b-8be9-c0d0b5fc48fb",                        [{"x":["overlapping","sequencing","consecutive","difficulty","correctly","identified","generating","chronological","similarity","architecture","difficult","including","sequential","different","resulting","embedding","supervised","permutation","fragments","convolutional","requiring","competing","combination","analytically","underlying","introduce","weighting","arbitrary","simulations","retrospective","properties","interpretation","predictions","appearance","selection","application","investigated","desirable","prevented","typically","interpretability","unfortunately","correlation","accessible","performance","importance","sacrificing","therefore","excellent","predictive","structure","illustrated","solutions","decomposition","advantage","nonlinear","experimental","hyperspectral","factorization","processing","optimization","techniques","objective","efficiency","nonnegative","particular","approximated","formulation","functions","literature","determines","extraction","corresponding","successfully","backgrounds","formation","annotation","information","practical","trainingtesting","punctuation","approaches","elementary","linguistic","improvements","characterized","available","vocabulary","collected","currently","computational","ambiguity","recognition","essential","sentences","handwriting","variations","contribute","character","verification","facilitate","challenging","developed","disambiguation","exceptional","morphology","difficulties","furthermore","efficient","estimation","penalized","parameters","specifically","unbalanced","dimensional","penalties","advantages","regression","regularization","algorithm","coordinate","experiments","substantial","algorithms","regularized","generalized","numerical","formulate","procedures","likelihood","simulated","screening","demonstrate","relatively","mathematical","usefulness","inference","obtaining","variables","graphical","approximation","computing","marginals","exponential","effectively","constraints","remaining","partitions","formalizing","variational","individual","expectations","relaxation","probabilistic","equivalent","framework","identical","reflection","variation","important","approximately","strengths","exploiting","empirical","convexity","comparing","quadratic","consequence","geometrically","iterative","platforms","extensive","combinatorial","projection","submodular","conceptually","parallelizability","straightforward","subroutines","flexibility","reformulate","footprint","evaluation","submodularity","denoising","minimization","principal","understanding","googlenet","nutritional","exploring","corrective","automatic","detection","localization","component","community","evidenced","consumption","comparable"],"y":[26,2,16,47,28,42,72,3,143,219,149,241,72,756,151,103,197,7,13,351,45,19,128,11,111,346,23,85,35,2,216,68,80,75,154,229,43,26,2,104,12,28,76,13,852,94,8,139,30,48,353,22,144,68,92,67,381,12,35,272,306,375,165,145,9,264,20,80,209,124,17,135,117,83,5,17,67,709,126,2,2,457,8,77,110,34,304,38,64,51,289,21,376,66,81,11,79,21,59,22,57,248,179,18,3,15,30,145,405,208,2,237,162,3,166,4,78,126,78,781,21,625,43,593,45,66,81,46,40,62,56,7,581,73,63,30,215,41,133,65,127,136,12,41,122,146,24,20,4,67,120,10,19,160,52,527,18,13,60,361,36,22,81,140,8,74,37,15,5,69,28,171,41,55,12,5,2,21,2,27,9,11,268,3,49,56,35,161,9,2,40,1,180,341,71,118,85,6,21,120],"type":"bar"},{"x":["overlapping","sequencing","consecutive","difficulty","correctly","identified ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4621,), (4621, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8083333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>to</span> <span style=''>Predict</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Independent</span> <span style=''>of</span> <span style=''>Span</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>how</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>multi</span> <span style=''>step</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(0, 255, 0, 0.33749999999999997);'>Conventional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>wait</span> <span style=''>until</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observing</span> <span style=''>actual</span> <span style=''>outcomes</span> <span style=''>before</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computations</span> <span style=''>to</span> <span style=''>update</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>If</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>are</span> <span style=''>made</span> <span style=''>at</span> <span style=''>a</span> <span style=''>high</span> <span style=''>rate</span> <span style=''>or</span> <span style=''>span</span> <span style=''>over</span> <span style=''>a</span> <span style=''>large</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>substantial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>can</span> <span style=''>be</span> <span style=''>required</span> <span style=''>to</span> <span style=''>store</span> <span style=''>all</span> <span style=''>relevant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observations</span> <span style=''>and</span> <span style=''>to</span> <span style=''>update</span> <span style=''>all</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>when</span> <span style=''>the</span> <span style=''>outcome</span> <span style=''>is</span> <span style=''>finally</span> <span style=''>observed</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>exact</span> <span style=''>same</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>can</span> <span style=''>be</span> <span style=''>learned</span> <span style=''>in</span> <span style=''>a</span> <span style=''>much</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3773584905660378);'>computationally</span> <span style=''>congenial</span> <span style=''>way</span> <span style=''>with</span> <span style=''>uniform</span> <span style=''>per</span> <span style=''>step</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>that</span> <span style=''>does</span> <span style=''>not</span> <span style=''>depend</span> <span style=''>on</span> <span style=''>the</span> <span style=''>span</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>We</span> <span style=''>apply</span> <span style=''>this</span> <span style=''>idea</span> <span style=''>to</span> <span style=''>various</span> <span style=''>settings</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>repeatedly</span> <span style=''>adding</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinear</span> <span style=''>Eigenproblems</span> <span style=''>in</span> <span style=''>Data</span> <span style=''>Analysis</span> <span style=''>Balanced</span> <span style=''>Graph</span> <span style=''>Cuts</span> <span style=''>and</span> <span style=''>the</span> <span style=''>RatioDCA</span> <span style=''>Prox</span> <br/><br/><span style=''>It</span> <span style=''>has</span> <span style=''>been</span> <span style=''>recently</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>a</span> <span style=''>large</span> <span style=''>class</span> <span style=''>of</span> <span style=''>balanced</span> <span style=''>graph</span> <span style=''>cuts</span> <span style=''>allows</span> <span style=''>for</span> <span style=''>an</span> <span style=''>exact</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relaxation</span> <span style=''>into</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>eigenproblem</span> <span style=''>We</span> <span style=''>review</span> <span style=''>briefly</span> <span style=''>some</span> <span style=''>of</span> <span style=''>these</span> <span style=''>results</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style=''>compute</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvectors</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>encompasses</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>as</span> <span style=''>special</span> <span style=''>cases</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>detailed</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>behavior</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style=''>then</span> <span style=''>discuss</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>in</span> <span style=''>the</span> <span style=''>area</span> <span style=''>of</span> <span style=''>balanced</span> <span style=''>graph</span> <span style=''>cuts</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Super</span> <span style=''>Samples</span> <span style=''>from</span> <span style=''>Kernel</span> <span style=''>Herding</span> <br/><br/><span style=''>We</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>herding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>spaces</span> <span style=''>by</span> <span style=''>using</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>trick</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>kernel</span> <span style=''>herding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>an</span> <span style=''>infinite</span> <span style=''>memory</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deterministic</span> <span style=''>process</span> <span style=''>that</span> <span style=''>learns</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>a</span> <span style=''>PDF</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>samples</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>kernel</span> <span style=''>herding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decreases</span> <span style=''>the</span> <span style=''>error</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expectations</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Hilbert</span> <span style=''>space</span> <span style=''>at</span> <span style=''>a</span> <span style=''>rate</span> <span style=''>O(1T)</span> <span style=''>which</span> <span style=''>is</span> <span style=''>much</span> <span style=''>faster</span> <span style=''>than</span> <span style=''>the</span> <span style=''>usual</span> <span style=''>O(1pT)</span> <span style=''>for</span> <span style=''>iid</span> <span style=''>random</span> <span style=''>samples</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3299492385786802);'>illustrate</span> <span style=''>kernel</span> <span style=''>herding</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.35593220338983056);'>approximating</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.5317073170731708);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.372093023255814);'>distributions</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Modular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Representation</span> <span style=''>of</span> <span style=''>Layered</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>Layered</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>have</span> <span style=''>greatly</span> <span style=''>improved</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>speech</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bioinformatics</span> <span style=''>However</span> <span style=''>it</span> <span style=''>is</span> <span style=''>still</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>discover</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpret</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>provided</span> <span style=''>by</span> <span style=''>a</span> <span style=''>layered</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>since</span> <span style=''>its</span> <span style=''>internal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>has</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>and</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>embedded</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>layers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Therefore</span> <span style=''>it</span> <span style=''>becomes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>by</span> <span style=''>which</span> <span style=''>layered</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understood</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extracting</span> <span style=''>a</span> <span style=''>global</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simplified</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>from</span> <span style=''>a</span> <span style=''>layered</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>network</span> <span style=''>analysis</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>detects</span> <span style='background-co ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12276945039257674)
# 	representation (0.13204853675945752)
# 	evaluation (0.09564596716630978)
# 	segmentation (0.0667380442541042)
# 	experimental (0.13597430406852248)
# 	information (0.25303354746609563)
# 	detection (0.12169878658101356)
# 	convolutional (0.1252676659528908)
# 	different (0.2698072805139186)
# 	recognition (0.13418986438258387)
#
# Some Statistics words are:
# 	stochastic (0.12562562562562563)
# 	variables (0.13613613613613615)
# 	statistical (0.15365365365365366)
# 	theoretical (0.15315315315315314)
# 	estimation (0.17667667667667666)
# 	algorithm (0.3908908908908909)
# 	distribution (0.18868868868868868)
# 	inference (0.1956956956956957)
# 	dimensional (0.1841841841841842)
# 	regression (0.1871871871871872)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8dc53fc2-4a45-479d-9dd9-01cde1d68aec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8dc53fc2-4a45-479d-9dd9-01cde1d68aec")) {                    Plotly.newPlot(                        "8dc53fc2-4a45-479d-9dd9-01cde1d68aec",                        [{"x":["overlapping","sequencing","consecutive","difficulty","correctly","identified","generating","chronological","similarity","architecture","difficult","including","sequential","different","resulting","embedding","supervised","permutation","fragments","convolutional","requiring","competing","combination","analytically","underlying","introduce","weighting","arbitrary","simulations","retrospective","properties","interpretation","predictions","appearance","selection","application","investigated","desirable","prevented","typically","interpretability","unfortunately","correlation","accessible","performance","importance","sacrificing","therefore","excellent","predictive","structure","illustrated","solutions","decomposition","advantage","nonlinear","experimental","hyperspectral","factorization","processing","optimization","techniques","objective","efficiency","nonnegative","particular","approximated","formulation","functions","literature","determines","extraction","corresponding","successfully","backgrounds","formation","annotation","information","practical","trainingtesting","punctuation","approaches","elementary","linguistic","improvements","characterized","available","vocabulary","collected","currently","computational","ambiguity","recognition","essential","sentences","handwriting","variations","contribute","character","verification","facilitate","challenging","developed","disambiguation","exceptional","morphology","difficulties","furthermore","efficient","estimation","penalized","parameters","specifically","unbalanced","dimensional","penalties","advantages","regression","regularization","algorithm","coordinate","experiments","substantial","algorithms","regularized","generalized","numerical","formulate","procedures","likelihood","simulated","screening","demonstrate","relatively","mathematical","usefulness","inference","obtaining","variables","graphical","approximation","computing","marginals","exponential","effectively","constraints","remaining","partitions","formalizing","variational","individual","expectations","relaxation","probabilistic","equivalent","framework","identical","reflection","variation","important","approximately","strengths","exploiting","empirical","convexity","comparing","quadratic","consequence","geometrically","iterative","platforms","extensive","combinatorial","projection","submodular","conceptually","parallelizability","straightforward","subroutines","flexibility","reformulate","footprint","evaluation","submodularity","denoising","minimization","principal","understanding","googlenet","nutritional","exploring","corrective","automatic","detection","localization","component","community","evidenced","consumption","comparable","outperforms","introducing","production","scheduling","processes","shortening","manufacturing","consisting","represented","environment","universal","situation","estimated","attention","responsiveness","generated","satisfactory","significant","completing","simulation","introduced","interactive","technique","traditionally","comparison","simulator","perspective","continually","complexity","increasing","expensive","demonstrated","denoisers","noiseless","infeasible","estimator","unprecedented","uniformity","extracted","geographically","varieties","international","employing","blindness","transform","discussed","symmetrical","naturally","concisely","continuous","evolution","according","illustrating","physiological","classifications","determin ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	metabolic
# 	invariances
# 	oscillates
# 	similitude
# 	hermitian
# 	quadrature
# 	linearnonlinear
# 	mcallester
# 	recombines
# 	investing
# 	portfolios
# 	embarrassingly
# 	nonconjugate
# 	concordant
# 	majorizer
# 	boundedness
# 	supersparse
# 	criminology
# 	prevalence
# 	confounders
# Some words which never appear in Statistics papers:
# 	trainingtesting
# 	punctuation
# 	disambiguation
# 	formalizing
# 	reflection
# 	nutritional
# 	shortening
# 	responsiveness
# 	denoisers
# 	blindness
# 	symmetrical
# 	concisely
# 	targeting
# 	advertisements
# 	advertisers
# 	preparing
# 	disturbance
# 	crosslingual
# 	coordinated
# 	elevation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.063631628932937e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.76
